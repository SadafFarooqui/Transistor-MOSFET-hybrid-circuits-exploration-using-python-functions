# %%
def open_circuit(row):
    from openpyxl import Workbook
    import openpyxl
    path = r"C:\Users\user122\Desktop\ANDcircuits.xlsx"
    wb_obj = openpyxl.load_workbook(path)
    sheet_obj = wb_obj.active
    cell_obj = sheet_obj.cell(row, column = 1)
    argv=cell_obj.value
    argv=argv.split('\n')
    a=[]
    for n in argv:
        n=n.split()
        a.extend([n])


    for i in range (len(a)):
        print("open circuiting the device" + str(i+1), "we get")
        nets=[]
        for n in argv:
            n=n.split()
            nets.extend([n])
        open_ccted=nets[i]
        nets.remove(open_ccted)
        import matplotlib.pyplot as plt
        import networkx as nx
        edges=[]
        for i in nets:
                if (i[-1]=="PMOS"or i[-1]=="NMOS"):
                    edges.extend([[i[1], i[3]]])
                else:
                    edges.extend([[i[1], i[2]]])
        G = nx.Graph()
        G.add_edges_from(edges)
        pos = nx.circular_layout(G)
        plt.figure()
        nx.draw(
            G, pos, edge_color='black', width=1, linewidths=1,
            node_size=500, node_color='pink', alpha=0.9,
            labels={node: node for node in G.nodes()}
        )
        count=1
        edge_labels={}
        for i in nets:
                if (i[-1]=="PMOS"or i[-1]=="NMOS"):
                    edge_labelsupdate={(tuple([i[1], i[3]])): i[2]+' '+i[-1]}
                    edge_labels=dict(list(edge_labels.items()) + list(edge_labelsupdate.items()))
                    count+=1
                else:
                    edge_labelsupdate={(tuple([i[1], i[2]])): i[1]+'(p)  '+i[-1]+'  ' +i[2]+'(n)' }
                    edge_labels=dict(list(edge_labels.items()) + list(edge_labelsupdate.items()))

        nx.draw_networkx_edge_labels(
            G, pos, edge_labels,
            font_color='red'
        )
        plt.axis('off')
        plt.show()
        if nx.is_connected(G):
            print('The resulting graph is connected')
        else:
            print('The resulting graph is disconnected')

# %%
open_circuit(5)
# Out:
# open circuiting the device1 we get
# The resulting graph is connected
# open circuiting the device2 we get
# The resulting graph is connected
# open circuiting the device3 we get
# The resulting graph is disconnected
# open circuiting the device4 we get
# The resulting graph is connected

# %%
open_circuit(52)
# Out:
# open circuiting the device1 we get
# The resulting graph is connected
# open circuiting the device2 we get
# The resulting graph is connected
# open circuiting the device3 we get
# The resulting graph is disconnected
# open circuiting the device4 we get
# The resulting graph is connected
